# %%
import pandas as pd
import numpy as np

# %%
lst_str_cols = ['R_OS_ID', 'MATERIAL_ID', 'STEEL_GRADE']
dict_dtypes = {x : 'str'  for x in lst_str_cols}
data = pd.read_csv('data_clean_new.csv', dtype=dict_dtypes)

# %% [markdown]
# R_OS_ID
# This is an unique ID for each individual process. Everything that happens (a production process, relocation of an item, a quality check etc.) has a operation step ID.
#
# MATERIAL_ID
# This is an unique ID for each product item. This ID remains the same throughout all process steps and can be used to aggregate data of different steps.
#
# PRODUCTION_LINE_NAME
# This column holds the information about the production line on which a process step takes place. As also non-technical processes are covered, it might also contain additional entries. In the following list (also available as xlsx-file), the description is given:
#
# | **PRODUCTION\_LINE\_NAME** | **DESCRIPTION**                       |
# | -------------------------- | ------------------------------------- |
# | **ANN**                    | ANN - Announcement                    |
# | **ATT**                    | ATT - Attach                          |
# | **B\_IN**                  | B\_IN - Book in                       |
# | **B\_OUT**                 | B\_OUT - Book out                     |
# | **BAF**                    | BAF - Set of batch annealing furnaces |
# | **BAF01**                  | BAF01 - Batch annealing furnace 01    |
# | **BAF02**                  | BAF02 - Batch annealing furnace 02    |
# | **BAF03**                  | BAF03 - Batch annealing furnace 03    |
# | **BAF04**                  | BAF04 - Batch annealing furnace 04    |
# | **BAF05**                  | BAF05 - Batch annealing furnace 05    |
# | **BAF06**                  | BAF06 - Batch annealing furnace 06    |
# | **BAF07**                  | BAF07 - Batch annealing furnace 07    |
# | **BAF08**                  | BAF08 - Batch annealing furnace 08    |
# | **BAF09**                  | BAF09 - Batch annealing furnace 09    |
# | **BAF10**                  | BAF10 - Batch annealing furnace 10    |
# | **BAF11**                  | BAF11 - Batch annealing furnace 11    |
# | **BAF12**                  | BAF12 - Batch annealing furnace 12    |
# | **BAF13**                  | BAF13 - Batch annealing furnace 13    |
# | **BAF14**                  | BAF14 - Batch annealing furnace 14    |
# | **BAF15**                  | BAF15 - Batch annealing furnace 15    |
# | **BAF16**                  | BAF16 - Batch annealing furnace 16    |
# | **BAF17**                  | BAF17 - Batch annealing furnace 17    |
# | **BAF18**                  | BAF18 - Batch annealing furnace 18    |
# | **BAF19**                  | BAF19 - Batch annealing furnace 19    |
# | **BAF20**                  | BAF20 - Batch annealing furnace 20    |
# | **BAF21**                  | BAF21 - Batch annealing furnace 21    |
# | **BAF22**                  | BAF22 - Batch annealing furnace 22    |
# | **BAF23**                  | BAF23 - Batch annealing furnace 23    |
# | **BAF24**                  | BAF24 - Batch annealing furnace 24    |
# | **CCM1**                   | CCM1 - CSP Caster 1                   |
# | **CGL1**                   | CGL1 - Cont. galvanizing line 1       |
# | **CGL1R**                  | CGL1R - CGL1 entry reject             |
# | **CSP1**                   | CSP - CSP line 1                      |
# | **CY**                     | CY - Coil yard                        |
# | **DC3**                    | DC3 - Manual change                   |
# | **DEL**                    | DEL - Delivery                        |
# | **DISP**                   | DISP - Dispatch                       |
# | **EAF1**                   | EAF1 - Electr. arc furnace            |
# | **EDTLOC**                 | EDTLOC - Location change              |
# | **HSC**                    | HSC - Hot mill sample cut             |
# | **HSM**                    | HSM - CSP Hot strip mill              |
# | **INSP\_C**                | INSP\_C - Coil inspection             |
# | **INTAKE**                 | INTAKE - Coil intake                  |
# | **LAB**                    | LAB - Laboratory                      |
# | **LF1**                    | LF1 - Ladle furnace                   |
# | **MAT\_COR**               | MAT\_COR - Data correction            |
# | **OP**                     | Outside processing                    |
# | **PLR**                    | PLR - PLTCM entry reject              |
# | **PLTCM**                  | PLTCM - Pickling tandem line          |
# | **PSH**                    | PSH - Shipment planned                |
# | **QC**                     | QC - Quality check                    |
# | **RDY**                    | RDY - Ready                           |
# | **RH1**                    | RH1 - Vacuum degassing                |
# | **SPM1**                   | SPM1 - Skin pass mill 1               |
# | **SPM1R**                  | SPM1R - SPM1 entry reject             |
# | **TF1**                    | TF1 - Tunnel furnace 1                |
#
# START_DATE
# The date time of the start of the given process instance.
#
# END_DATE
# The date time of the end of the given process instance.
#
# STEEL_GRADE
# This column describes, which steel grade the product item is made of. The steel grades are just represented by IDs.
#
# WIDTH
# This column contains the normalized width values of the products. In case a process refers to heats and not slabs or coils, the value might be zero.
#
# WEIGHT
# This column contains the normalized weight values of the products. In case a process refers to heats, the weight might be higher, while slabs or coils typically would have lower values.
#
# THICKNESS
# This column contains the normalized thickness values of the products. In case a process refers to heats and not slabs or coils, the value might be zero.
#
# LENGTH
# This column contains the normalized length values of the products. In case a process refers to heats and not slabs or coils, the value might be zero.
#
# DURATION
# This column contains the process instance duration in full time-delta format.
#
# DURATION_SECONDS
# This column contains the process instance duration in seconds.

# %%
data
# Out:
#          Unnamed: 0    R_OS_ID MATERIAL_ID PRODUCTION_LINE_NAME  \
# 0                 0  2567987.0   1589415.0                 EAF1
# 1                 1  2567987.0   1589421.0                 EAF1
# 2                 2  2567987.0   1589424.0                 EAF1
# 3                 3  2568127.0   1589415.0                  LF1
# 4                 4  2568127.0   1589421.0                  LF1
# ...             ...        ...         ...                  ...
# 1569485     1573310        NaN         NaN                  HSM
# 1569486     1573311        NaN         NaN                  HSM
# 1569487     1573312        NaN         NaN                  HSM
# 1569488     1573313        NaN         NaN                  HSM
# 1569489     1573314        NaN         NaN                PLTCM
#
#                   START_DATE             END_DATE STEEL_GRADE     WIDTH  \
# 0        2018-06-27 03:19:59  2018-06-27 03:55:50        53.0  0.000000
# 1        2018-06-27 03:19:59  2018-06-27 03:55:50        53.0  0.000000
# 2        2018-06-27 03:19:59  2018-06-27 03:55:50        53.0  0.000000
# 3        2018-06-27 03:56:03  2018-06-27 04:54:10        53.0  0.000000
# 4        2018-06-27 03:56:03  2018-06-27 04:54:10        53.0  0.000000
# ...                      ...                  ...         ...       ...
# 1569485  2019-03-06 16:57:28  2019-03-06 16:57:28         NaN  0.715020
# 1569486  2019-03-06 16:57:28  2019-03-06 16:57:28         NaN  0.715020
# 1569487  2019-03-06 16:57:28  2019-03-06 16:57:28         NaN  0.715020
# 1569488  2019-03-06 16:57:28  2019-03-06 16:57:28         NaN  0.715020
# 1569489  2019-02-12 04:59:36  2019-02-12 05:36:34         NaN  0.710006
#
#            WEIGHT  THICKNESS    LENGTH         DURATION  DURATION_SECONDS
# 0        0.863762   0.000000  0.000000  0 days 00:35:51            2151.0
# 1        0.863762   0.000000  0.000000  0 days 00:35:51            2151.0
# 2        0.863762   0.000000  0.000000  0 days 00:35:51            2151.0
# 3        0.871686   0.000000  0.000000  0 days 00:58:07            3487.0
# 4        0.871686   0.000000  0.000000  0 days 00:58:07            3487.0
# ...           ...        ...       ...              ...               ...
# 1569485  0.041554   0.220425  0.000306  0 days 00:00:00               0.0
# 1569486  0.041554   0.220425  0.000306  0 days 00:00:00               0.0
# 1569487  0.041554   0.220425  0.000306  0 days 00:00:00               0.0
# 1569488  0.021366   0.220425  0.000306  0 days 00:00:00               0.0
# 1569489  0.056524   0.019660  0.033334  0 days 00:36:58            2218.0
#
# [1569490 rows x 13 columns]

# %%
# Find duplicates 
df_no = data[list(data.columns)[1:]]
duplicates = df_no[df_no.duplicated(keep='first')]
duplicates
# Out:
#            R_OS_ID MATERIAL_ID PRODUCTION_LINE_NAME           START_DATE  \
# 687      2596397.0   1359537.0                  LF1  2018-06-30 18:49:54
# 1089     2596979.0   1359588.0                  LF1  2018-06-30 21:06:18
# 2912     2599431.0   1363770.0                 EAF1  2018-07-01 09:58:08
# 4657     2601687.0   1364025.0                  LF1  2018-07-01 18:00:46
# 4658     2601687.0   1364025.0                  LF1  2018-07-01 18:00:46
# ...            ...         ...                  ...                  ...
# 1569483        NaN         NaN                  HSM  2019-03-06 16:57:28
# 1569484        NaN         NaN                  HSM  2019-03-06 16:57:28
# 1569485        NaN         NaN                  HSM  2019-03-06 16:57:28
# 1569486        NaN         NaN                  HSM  2019-03-06 16:57:28
# 1569487        NaN         NaN                  HSM  2019-03-06 16:57:28
#
#                     END_DATE STEEL_GRADE    WIDTH    WEIGHT  THICKNESS  \
# 687      2018-06-30 20:03:41        32.0  0.00000  0.887121   0.000000
# 1089     2018-06-30 22:17:29        32.0  0.00000  0.862067   0.000000
# 2912     2018-07-01 10:33:19         8.0  0.00000  0.879508   0.000000
# 4657     2018-07-01 18:54:27        48.0  0.00000  0.853448   0.000000
# 4658     2018-07-01 18:54:27        48.0  0.00000  0.853448   0.000000
# ...                      ...         ...      ...       ...        ...
# 1569483  2019-03-06 16:57:28         NaN  0.71502  0.037516   0.220425
# 1569484  2019-03-06 16:57:28         NaN  0.71502  0.041554   0.220425
# 1569485  2019-03-06 16:57:28         NaN  0.71502  0.041554   0.220425
# 1569486  2019-03-06 16:57:28         NaN  0.71502  0.041554   0.220425
# 1569487  2019-03-06 16:57:28         NaN  0.71502  0.041554   0.220425
#
#            LENGTH         DURATION  DURATION_SECONDS
# 687      0.000000  0 days 01:13:47            4427.0
# 1089     0.000000  0 days 01:11:11            4271.0
# 2912     0.000000  0 days 00:35:11            2111.0
# 4657     0.000000  0 days 00:53:41            3221.0
# 4658     0.000000  0 days 00:53:41            3221.0
# ...           ...              ...               ...
# 1569483  0.000306  0 days 00:00:00               0.0
# 1569484  0.000306  0 days 00:00:00               0.0
# 1569485  0.000306  0 days 00:00:00               0.0
# 1569486  0.000306  0 days 00:00:00               0.0
# 1569487  0.000306  0 days 00:00:00               0.0
#
# [30755 rows x 12 columns]

# %%
# data.replace(['BAF01', 'BAF02', 'BAF03', 'BAF04', 'BAF05', 'BAF06',
#        'BAF07', 'BAF08', 'BAF10', 'BAF11', 'BAF12', 'BAF13', 'BAF14',
#        'BAF15', 'BAF16', 'BAF17', 'BAF18', 'BAF19', 'BAF20', 'BAF21',
#        'BAF22', 'BAF23', 'BAF24'],"BAF",inplace=True)
# data.replace(['CGL', 'CGL1'],"CGL",inplace=True)
# data.replace(['SPM', 'SPM1', 'SPM1R'],"SPM",inplace=True)
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

print("Negative duration Count")
figure(figsize=(8, 6), dpi=80)
data[data.DURATION_SECONDS<0].groupby("PRODUCTION_LINE_NAME").count()["R_OS_ID"].sort_values(ascending=False).plot.bar(rot=45,title='Negative Duration Count Based on Production Line')
plt.savefig('negative_duration_Count.jpg')
# Out:
# Negative duration Count

# %%
df_only_na = data[data.isnull().any(axis=1)]
df_only_na[df_only_na["DURATION_SECONDS"]<0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, R_OS_ID, MATERIAL_ID, PRODUCTION_LINE_NAME, START_DATE, END_DATE, STEEL_GRADE, WIDTH, WEIGHT, THICKNESS, LENGTH, DURATION, DURATION_SECONDS]
# Index: []

# %%
from matplotlib.pyplot import figure
print("NA Count")
figure(figsize=(8, 6), dpi=80)
df_only_na.groupby("PRODUCTION_LINE_NAME").count()["END_DATE"].sort_values(ascending=False).plot.bar(rot=45,title='NA Count Based on Production Line')
plt.savefig('na_Count.jpg')
# Out:
# NA Count

# %%
print(" \nCount total NaN at each column : \n\n",
      data.isnull().sum())
# Out:
#
# Count total NaN at each column :
#
#  Unnamed: 0                 0
# R_OS_ID                 3818
# MATERIAL_ID             3818
# PRODUCTION_LINE_NAME       0
# START_DATE                 0
# END_DATE                   0
# STEEL_GRADE             3818
# WIDTH                      0
# WEIGHT                     0
# THICKNESS                  0
# LENGTH                     0
# DURATION                   0
# DURATION_SECONDS           0
# dtype: int64

# %% [markdown]
# R_OS_ID is an unique ID for each individual process. Everything that happens has a operation step ID.
#
# The MATERIAL_ID is an unique ID for each product item. This ID remains the same throughout all process steps and can be used to aggregate data of different steps.
#
# PRODUCTION_LINE_NAME This column holds the information about the production line on which a process step takes place. As also non-technical processes are covered, it might also contain additional entries. In the following list (also available as xlsx-file), the description is given:

# %%
df = df_no.drop_duplicates().copy()
len(df) + len(duplicates) == len(data)
# Out:
# True

# %%
try_material = df[df["MATERIAL_ID"]=="1589415.0"]
try_material.rename(columns={'END_DATE': 'time:timestamp', 
'MATERIAL_ID': 'case:concept:name', 'PRODUCTION_LINE_NAME': 'concept:name'}, inplace=True)
try_material.sort_values("time:timestamp",inplace=True)
display(try_material)

import pm4py
import pandas as pd
from pm4py.objects.log.util import dataframe_utils
from pm4py.objects.conversion.log import converter as log_converter

log = log_converter.apply(try_material)

process_tree = pm4py.discover_tree_inductive(log)
bpmn_model = pm4py.convert_to_bpmn(process_tree)
pm4py.view_bpmn(bpmn_model)
pm4py.save_vis_bpmn(bpmn_model,file_path='material1589415.jpg')
# Out:
# /home/roger/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-10-38b2f01871c9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   try_material.sort_values("time:timestamp",inplace=True)
#           R_OS_ID case:concept:name concept:name           START_DATE  \
# 0       2567987.0         1589415.0         EAF1  2018-06-27 03:19:59
# 3       2568127.0         1589415.0          LF1  2018-06-27 03:56:03
# 407490  3154923.0         1589415.0          PSH  2018-09-27 14:37:49
# 407492  3154923.0         1589415.0          PSH  2018-09-27 14:37:49
# 407617  3155147.0         1589415.0          TF1  2018-09-27 14:42:12
# 407633  3155181.0         1589415.0          PSH  2018-09-27 14:58:55
# 407491  3154923.0         1589415.0         DISP  2018-09-27 14:37:49
# 407489  3154923.0         1589415.0         DISP  2018-09-27 14:37:49
# 416131  3167273.0         1589415.0         CCM1  2018-09-29 11:40:56
# 416132  3167275.0         1589415.0         CCM1  2018-09-29 11:40:56
# 416190  3167349.0         1589415.0       EDTLOC  2018-09-29 11:59:43
# 419663  3171649.0         1589415.0          DC3  2018-09-30 13:08:37
# 407632  3155177.0         1589415.0         DISP  2018-09-27 14:58:55
# 407634  3155183.0         1589415.0         DISP  2018-09-27 14:58:55
#
#              time:timestamp STEEL_GRADE     WIDTH    WEIGHT  THICKNESS  \
# 0       2018-06-27 03:55:50        53.0  0.000000  0.863762   0.000000
# 3       2018-06-27 04:54:10        53.0  0.000000  0.871686   0.000000
# 407490  2018-09-27 14:37:49        36.0  0.572225  0.145921   0.054007
# 407492  2018-09-27 14:37:49        36.0  0.572485  0.146025   0.054010
# 407617  2018-09-27 14:56:24        36.0  0.882631  0.134124   0.770115
# 407633  2018-09-27 14:58:55        36.0  0.738746  0.133082   0.025401
# 407491  2018-09-29 08:10:20        36.0  0.572225  0.145921   0.054007
# 407489  2018-09-29 08:25:17        36.0  0.571672  0.146497   0.054005
# 416131  2018-09-29 11:40:56        36.0  0.719198  0.134135   0.770115
# 416132  2018-09-29 11:40:56        36.0  0.724770  0.134141   0.770115
# 416190  2018-09-29 11:59:43        36.0  0.718524  0.137220   0.045793
# 419663  2018-09-30 13:08:37        36.0  0.567372  0.068026   0.005003
# 407632  2018-10-05 11:55:49        36.0  0.738240  0.134130   0.025400
# 407634  2018-10-05 11:55:50        36.0  0.738746  0.133082   0.025401
#
#           LENGTH         DURATION  DURATION_SECONDS
# 0       0.000000  0 days 00:35:51            2151.0
# 3       0.000000  0 days 00:58:07            3487.0
# 407490  0.049093  0 days 00:00:00               0.0
# 407492  0.048952  0 days 00:00:00               0.0
# 407617  0.002129  0 days 00:14:12             852.0
# 407633  0.072778  0 days 00:00:00               0.0
# 407491  0.049093  1 days 17:32:31          149551.0
# 407489  0.049236  1 days 17:47:28          150448.0
# 416131  0.002613  0 days 00:00:00               0.0
# 416132  0.002613  0 days 00:00:00               0.0
# 416190  0.041675  0 days 00:00:00               0.0
# 419663  0.210733  0 days 00:00:00               0.0
# 407632  0.072961  7 days 20:56:54          680214.0
# 407634  0.072778  7 days 20:56:55          680215.0
# <ipython-input-10-38b2f01871c9>:14: DeprecatedWarning: discover_tree_inductive is deprecated as of 2.2.2 and will be removed in 2.4.0. discover_tree_inductive is deprecated, use discover_process_tree_inductive
#   process_tree = pm4py.discover_tree_inductive(log)

# %%
print(" \nCount total NaN at each column : \n\n",
      df.isnull().sum())
# Out:
#
# Count total NaN at each column :
#
#  R_OS_ID                 3580
# MATERIAL_ID             3580
# PRODUCTION_LINE_NAME       0
# START_DATE                 0
# END_DATE                   0
# STEEL_GRADE             3580
# WIDTH                      0
# WEIGHT                     0
# THICKNESS                  0
# LENGTH                     0
# DURATION                   0
# DURATION_SECONDS           0
# dtype: int64

# %% [raw]
# df['MATERIAL_ID'] = df['MATERIAL_ID'].fillna(-1)
# df['MATERIAL_ID'] = df['MATERIAL_ID'].astype(int)
# df['MATERIAL_ID'] = df['MATERIAL_ID'].astype(str)
# df['MATERIAL_ID'] = df['MATERIAL_ID'].replace('-1', np.nan)
#
# df['R_OS_ID'] = df['R_OS_ID'].fillna(-1)
# df['R_OS_ID'] = df['R_OS_ID'].astype(int)
# df['R_OS_ID'] = df['R_OS_ID'].astype(str)
# df['R_OS_ID'] = df['R_OS_ID'].replace('-1', np.nan)
#
# df['STEEL_GRADE'] = df['STEEL_GRADE'].fillna(-1)
# df['STEEL_GRADE'] = df['STEEL_GRADE'].astype(int)
# df['STEEL_GRADE'] = df['STEEL_GRADE'].astype(str)
# df['STEEL_GRADE'] = df['STEEL_GRADE'].replace('-1', np.nan)

# %%
print("Negative duration fraction: "+"{:.2%}".format(len(data[data.DURATION_SECONDS<0])/len(data)))
print("NA records fraction: "+"{:.2%}".format(data["R_OS_ID"].isnull().sum()/len(data)))
print("Duplicates fraction: " +"{:.2%}".format(len(duplicates)/len(data)))
# # after drop na
df_no_na = df.dropna(inplace = False)
# print("Negative duration fraction: "+"{:.2%}".format(len(df_no_na[df_no_na.DURATION_SECONDS<0])/len(df_no_na)))
# print("NA records fraction: "+"{:.2%}".format(df_no_na["START_DATE"].isnull().sum()/len(df_no_na)))

# NULL data
df_only_na = data[data.isnull().any(axis=1)]
# Out:
# Negative duration fraction: 17.23%
# NA records fraction: 0.24%
# Duplicates fraction: 1.92%

# %%
# Filter out negative duration time
df = df[df["DURATION_SECONDS"] >= 0]

# %%
# Filter NAs
df.dropna(inplace = True)

# %%
# df.to_csv('final_data_noNA_noDup_posDur.csv', index=False)

# %%
df.rename(columns={'END_DATE': 'time:timestamp', 
'MATERIAL_ID': 'case:concept:name', 'PRODUCTION_LINE_NAME': 'concept:name'}, inplace=True)
display(df)
# Out:
#             R_OS_ID case:concept:name concept:name           START_DATE  \
# 0         2567987.0         1589415.0         EAF1  2018-06-27 03:19:59
# 1         2567987.0         1589421.0         EAF1  2018-06-27 03:19:59
# 2         2567987.0         1589424.0         EAF1  2018-06-27 03:19:59
# 3         2568127.0         1589415.0          LF1  2018-06-27 03:56:03
# 4         2568127.0         1589421.0          LF1  2018-06-27 03:56:03
# ...             ...               ...          ...                  ...
# 1566021  19878033.0         1914717.0          LF1  2019-06-29 15:43:02
# 1566022  19878035.0          114720.0          LF1  2019-06-29 15:43:02
# 1566023  19878037.0          114723.0        PLTCM  2019-06-29 16:26:51
# 1566024  19878039.0          114726.0          PSH  2019-06-29 16:37:31
# 1566025  19941711.0         1919259.0         DISP  2019-06-29 16:37:31
#
#               time:timestamp STEEL_GRADE     WIDTH    WEIGHT  THICKNESS  \
# 0        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 1        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 2        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 3        2018-06-27 04:54:10         3.0  0.000000  0.871686   0.000000
# 4        2018-06-27 04:54:10         3.0  0.000000  0.871686   0.000000
# ...                      ...         ...       ...       ...        ...
# 1566021  2019-06-29 16:35:30         3.0  0.000000  0.908112   0.000000
# 1566022  2019-06-29 16:35:30         3.0  0.000000  0.908112   0.000000
# 1566023  2019-06-29 16:41:55         3.0  0.577361  0.129164   0.005387
# 1566024  2019-06-29 16:37:31         3.0  0.567411  0.133393   0.016508
# 1566025  2019-07-11 13:19:20         0.0  0.567411  0.133393   0.016508
#
#            LENGTH          DURATION  DURATION_SECONDS
# 0        0.000000   0 days 00:35:51            2151.0
# 1        0.000000   0 days 00:35:51            2151.0
# 2        0.000000   0 days 00:35:51            2151.0
# 3        0.000000   0 days 00:58:07            3487.0
# 4        0.000000   0 days 00:58:07            3487.0
# ...           ...               ...               ...
# 1566021  0.000000   0 days 00:52:28            3148.0
# 1566022  0.000000   0 days 00:52:28            3148.0
# 1566023  0.434656   0 days 00:15:04             904.0
# 1566024  0.146958   0 days 00:00:00               0.0
# 1566025  0.146958  11 days 20:41:49         1024909.0
#
# [1270935 rows x 12 columns]

# %%
df["concept:name"].sort_values().unique()
# Out:
# array(['ATT', 'BAF01', 'BAF02', 'BAF03', 'BAF04', 'BAF05', 'BAF06',
#        'BAF07', 'BAF08', 'BAF10', 'BAF11', 'BAF12', 'BAF13', 'BAF14',
#        'BAF15', 'BAF16', 'BAF17', 'BAF18', 'BAF19', 'BAF20', 'BAF21',
#        'BAF22', 'BAF23', 'BAF24', 'CCM1', 'CGL', 'CGL1', 'DC3', 'DISP',
#        'EAF1', 'EDITQC', 'EDTLOC', 'HSC', 'HSM', 'INSP_C', 'LAB', 'LF1',
#        'PLR', 'PLTCM', 'PSH', 'QC', 'RH1', 'SPM', 'SPM1', 'SPM1R', 'SS',
#        'TF1', 'TRGUPD'], dtype=object)

# %%
df.replace(['BAF01', 'BAF02', 'BAF03', 'BAF04', 'BAF05', 'BAF06',
       'BAF07', 'BAF08', 'BAF10', 'BAF11', 'BAF12', 'BAF13', 'BAF14',
       'BAF15', 'BAF16', 'BAF17', 'BAF18', 'BAF19', 'BAF20', 'BAF21',
       'BAF22', 'BAF23', 'BAF24'],"BAF",inplace=True)
df.replace(['CGL', 'CGL1'],"CGL",inplace=True)
df.replace(['SPM', 'SPM1', 'SPM1R'],"SPM",inplace=True)

# %%
df["concept:name"].sort_values().unique()
# Out:
# array(['ATT', 'BAF', 'CCM1', 'CGL', 'DC3', 'DISP', 'EAF1', 'EDITQC',
#        'EDTLOC', 'HSC', 'HSM', 'INSP_C', 'LAB', 'LF1', 'PLR', 'PLTCM',
#        'PSH', 'QC', 'RH1', 'SPM', 'SS', 'TF1', 'TRGUPD'], dtype=object)

# %%
df
# Out:
#             R_OS_ID case:concept:name concept:name           START_DATE  \
# 0         2567987.0         1589415.0         EAF1  2018-06-27 03:19:59
# 1         2567987.0         1589421.0         EAF1  2018-06-27 03:19:59
# 2         2567987.0         1589424.0         EAF1  2018-06-27 03:19:59
# 3         2568127.0         1589415.0          LF1  2018-06-27 03:56:03
# 4         2568127.0         1589421.0          LF1  2018-06-27 03:56:03
# ...             ...               ...          ...                  ...
# 1566021  19878033.0         1914717.0          LF1  2019-06-29 15:43:02
# 1566022  19878035.0          114720.0          LF1  2019-06-29 15:43:02
# 1566023  19878037.0          114723.0        PLTCM  2019-06-29 16:26:51
# 1566024  19878039.0          114726.0          PSH  2019-06-29 16:37:31
# 1566025  19941711.0         1919259.0         DISP  2019-06-29 16:37:31
#
#               time:timestamp STEEL_GRADE     WIDTH    WEIGHT  THICKNESS  \
# 0        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 1        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 2        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 3        2018-06-27 04:54:10         3.0  0.000000  0.871686   0.000000
# 4        2018-06-27 04:54:10         3.0  0.000000  0.871686   0.000000
# ...                      ...         ...       ...       ...        ...
# 1566021  2019-06-29 16:35:30         3.0  0.000000  0.908112   0.000000
# 1566022  2019-06-29 16:35:30         3.0  0.000000  0.908112   0.000000
# 1566023  2019-06-29 16:41:55         3.0  0.577361  0.129164   0.005387
# 1566024  2019-06-29 16:37:31         3.0  0.567411  0.133393   0.016508
# 1566025  2019-07-11 13:19:20         0.0  0.567411  0.133393   0.016508
#
#            LENGTH          DURATION  DURATION_SECONDS
# 0        0.000000   0 days 00:35:51            2151.0
# 1        0.000000   0 days 00:35:51            2151.0
# 2        0.000000   0 days 00:35:51            2151.0
# 3        0.000000   0 days 00:58:07            3487.0
# 4        0.000000   0 days 00:58:07            3487.0
# ...           ...               ...               ...
# 1566021  0.000000   0 days 00:52:28            3148.0
# 1566022  0.000000   0 days 00:52:28            3148.0
# 1566023  0.434656   0 days 00:15:04             904.0
# 1566024  0.146958   0 days 00:00:00               0.0
# 1566025  0.146958  11 days 20:41:49         1024909.0
#
# [1270935 rows x 12 columns]

# %%
import pm4py
import pandas as pd
from pm4py.objects.log.util import dataframe_utils
from pm4py.objects.conversion.log import converter as log_converter

# log_csv = pd.read_csv('<path_to_csv_file.csv>', sep=',')
# log_csv = dataframe_utils.convert_timestamp_columns_in_df(log_csv)
# log_csv = log_csv.sort_values('<timestamp_column>')
# event_log = log_converter.apply(log_csv)

# df = dataframe_utils.convert_timestamp_columns_in_df(df)



display(df)
log = log_converter.apply(df)

process_tree = pm4py.discover_tree_inductive(log)
bpmn_model = pm4py.convert_to_bpmn(process_tree)
pm4py.view_bpmn(bpmn_model)
# Out:
#             R_OS_ID case:concept:name concept:name           START_DATE  \
# 0         2567987.0         1589415.0         EAF1  2018-06-27 03:19:59
# 1         2567987.0         1589421.0         EAF1  2018-06-27 03:19:59
# 2         2567987.0         1589424.0         EAF1  2018-06-27 03:19:59
# 3         2568127.0         1589415.0          LF1  2018-06-27 03:56:03
# 4         2568127.0         1589421.0          LF1  2018-06-27 03:56:03
# ...             ...               ...          ...                  ...
# 1566021  19878033.0         1914717.0          LF1  2019-06-29 15:43:02
# 1566022  19878035.0          114720.0          LF1  2019-06-29 15:43:02
# 1566023  19878037.0          114723.0        PLTCM  2019-06-29 16:26:51
# 1566024  19878039.0          114726.0          PSH  2019-06-29 16:37:31
# 1566025  19941711.0         1919259.0         DISP  2019-06-29 16:37:31
#
#               time:timestamp STEEL_GRADE     WIDTH    WEIGHT  THICKNESS  \
# 0        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 1        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 2        2018-06-27 03:55:50         3.0  0.000000  0.863762   0.000000
# 3        2018-06-27 04:54:10         3.0  0.000000  0.871686   0.000000
# 4        2018-06-27 04:54:10         3.0  0.000000  0.871686   0.000000
# ...                      ...         ...       ...       ...        ...
# 1566021  2019-06-29 16:35:30         3.0  0.000000  0.908112   0.000000
# 1566022  2019-06-29 16:35:30         3.0  0.000000  0.908112   0.000000
# 1566023  2019-06-29 16:41:55         3.0  0.577361  0.129164   0.005387
# 1566024  2019-06-29 16:37:31         3.0  0.567411  0.133393   0.016508
# 1566025  2019-07-11 13:19:20         0.0  0.567411  0.133393   0.016508
#
#            LENGTH          DURATION  DURATION_SECONDS
# 0        0.000000   0 days 00:35:51            2151.0
# 1        0.000000   0 days 00:35:51            2151.0
# 2        0.000000   0 days 00:35:51            2151.0
# 3        0.000000   0 days 00:58:07            3487.0
# 4        0.000000   0 days 00:58:07            3487.0
# ...           ...               ...               ...
# 1566021  0.000000   0 days 00:52:28            3148.0
# 1566022  0.000000   0 days 00:52:28            3148.0
# 1566023  0.434656   0 days 00:15:04             904.0
# 1566024  0.146958   0 days 00:00:00               0.0
# 1566025  0.146958  11 days 20:41:49         1024909.0
#
# [1270935 rows x 12 columns]
# <ipython-input-20-f44af6fc01fb>:18: DeprecatedWarning: discover_tree_inductive is deprecated as of 2.2.2 and will be removed in 2.4.0. discover_tree_inductive is deprecated, use discover_process_tree_inductive
#   process_tree = pm4py.discover_tree_inductive(log)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f44af6fc01fb> in <module>
#      16 log = log_converter.apply(df)
#      17
# ---> 18 process_tree = pm4py.discover_tree_inductive(log)
#      19 bpmn_model = pm4py.convert_to_bpmn(process_tree)
#      20 pm4py.view_bpmn(bpmn_model)
#
# ~/anaconda3/lib/python3.8/site-packages/deprecation.py in _inner(*args, **kwargs)
#     258                               stacklevel=2)
#     259
# --> 260             return function(*args, **kwargs)
#     261         return _inner
#     262     return _function_wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/discovery.py in discover_tree_inductive(log, noise_threshold)
#     223         Process tree object
#     224     """
# --> 225     return discover_process_tree_inductive(log, noise_threshold)
#     226
#     227
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/discovery.py in discover_process_tree_inductive(log, noise_threshold)
#     201     parameters = get_properties(log)
#     202     parameters[inductive_miner.Variants.IM_CLEAN.value.Parameters.NOISE_THRESHOLD] = noise_threshold
# --> 203     return inductive_miner.apply_tree(log, variant=inductive_miner.Variants.IM_CLEAN, parameters=parameters)
#     204
#     205
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/algo/discovery/inductive/algorithm.py in apply_tree(log, parameters, variant)
#     120         Process tree
#     121     """
# --> 122     return exec_utils.get_variant(variant).apply_tree(log, parameters=parameters)
#     123
#     124
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/algo/discovery/inductive/variants/im_clean/algorithm.py in apply_tree(event_log, parameters)
#     109     if threshold == 0.0:
#     110         # keep one trace per variant; more performant
# --> 111         event_log = filtering_utils.keep_one_trace_per_variant(event_log, parameters=parameters)
#     112
#     113     tree = inductive_miner(event_log, discover_dfg.apply(event_log, parameters={
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/objects/log/util/filtering_utils.py in keep_one_trace_per_variant(log, parameters)
#      40     new_log = EventLog()
#      41     if log is not None:
# ---> 42         variants = variants_module.get_variants(log, parameters=parameters)
#      43         for var in variants:
#      44             new_log.append(variants[var][0])
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/statistics/variants/log/get.py in get_variants(log, parameters)
#      79     """
#      80
# ---> 81     variants_trace_idx = get_variants_from_log_trace_idx(log, parameters=parameters)
#      82
#      83     all_var = convert_variants_trace_idx_to_trace_obj(log, variants_trace_idx)
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/statistics/variants/log/get.py in get_variants_from_log_trace_idx(log, parameters)
#     149     variants = {}
#     150     for trace_idx, trace in enumerate(log):
# --> 151         variant = variants_util.get_variant_from_trace(trace, parameters=parameters)
#     152         if variant not in variants:
#     153             variants[variant] = []
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/util/variants_util.py in get_variant_from_trace(trace, parameters)
#      77
#      78     if VARIANT_SPECIFICATION == VariantsSpecifications.STRING:
# ---> 79         return ",".join([x[activity_key] for x in trace])
#      80     elif VARIANT_SPECIFICATION == VariantsSpecifications.LIST:
#      81         return tuple([x[activity_key] for x in trace])
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/util/variants_util.py in <listcomp>(.0)
#      77
#      78     if VARIANT_SPECIFICATION == VariantsSpecifications.STRING:
# ---> 79         return ",".join([x[activity_key] for x in trace])
#      80     elif VARIANT_SPECIFICATION == VariantsSpecifications.LIST:
#      81         return tuple([x[activity_key] for x in trace])
#
# ~/anaconda3/lib/python3.8/site-packages/pm4py/objects/log/obj.py in __getitem__(self, key)
#      58
#      59     def __getitem__(self, key):
# ---> 60         return self._dict[key]
#      61
#      62     def __setitem__(self, key, value):
#
# KeyboardInterrupt:

# %%
pm4py.save_vis_bpmn(bpmn_model,file_path='vis.jpg')
